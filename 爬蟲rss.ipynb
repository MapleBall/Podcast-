# %%
import feedparser
import requests
import time
import random
import re
import json
from bs4 import BeautifulSoup
import os

def sanitize_filename(filename):
    # 定義要移除的非法字符集合
    illegal_chars = set('/\\%*|"')

    # 創建一個映射表，將所有非法字符映射為空字串
    translation_table = str.maketrans('', '', ''.join(illegal_chars))
    
    # 使用 translate 方法來應用映射表，移除非法字符
    sanitized_filename = filename.translate(translation_table)
    
    return sanitized_filename

def download_mp3(url, folder_path, filename):
    response = requests.get(url)
    if response.status_code == 200:
        with open(os.path.join(folder_path, filename), 'wb') as file:
            file.write(response.content)
        print(f"檔案下載完成: {filename}")
    else:
        print("無法下載檔案")

def get_rss_file(newsurl, test_n, parent_folder_path=None):
    
    def get_title_name(url):
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            title = soup.find_all("title")[0].text
            return sanitize_filename(title)
    
    # 獲取節目標題，並在母資料夾內建立子資料夾
    if newsurl[13:21] == "firstory" or newsurl[14:23] == "buzzsprout":
        response = requests.get(newsurl)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            title = soup.find_all("title")[0].text
            title = sanitize_filename(title)
    else:
        title = get_title_name(newsurl)
    
    # 如果指定了母資料夾，則在其內建立子資料夾
    if parent_folder_path:
        folder_path = os.path.join(parent_folder_path, title)
    else:
        folder_path = title
    
    # 創建資料夾
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
    
    if newsurl[13:21] == "firstory":
        n = len(soup.find_all("item"))
        print(title, "一共", n, "集")

        if n <= 2 or test_n == "all":
            test_n = n

        for i in range(test_n):
            time.sleep(random.randrange(1, 5))
            mp3_url = soup.find_all("item")[i].find('enclosure').get('url')
            name = soup.find_all("item")[i].find('itunes:title').text
            sanitized_name = sanitize_filename(name)
            download_mp3(mp3_url, folder_path, sanitized_name + ".mp3")

    elif newsurl[14:23] == "buzzsprout":
        n = len(soup.find_all("item"))
        print(title, "一共", n, "集")

        if n <= 2 or test_n == "all":
            test_n = n

        for i in range(test_n):
            time.sleep(random.randrange(1, 5))
            mp3_url = soup.find_all("item")[i].find('enclosure').get('url')
            name = soup.find_all("item")[i].find('title').text
            sanitized_name = sanitize_filename(name)
            download_mp3(mp3_url, folder_path, sanitized_name + ".mp3")
    else:
        file = feedparser.parse(newsurl)
        n = len(file["entries"])
        print(title, "一共", n, "集")

        if n <= 2 or test_n == "all":
            test_n = n
        else:
            test_n = int(test_n)
            if test_n > n:
                test_n = n

        for i in range(test_n):
            time.sleep(random.randrange(1, 5))
            try:
                mp3_url = file["entries"][i]["links"][1]["href"]
            except IndexError:
                mp3_url = file["entries"][i]["links"][0]["href"]
            except Exception as e:
                print(f"Error fetching MP3 URL for episode {i}: {e}")
                continue
            
            name = file["entries"][i]["title"]
            sanitized_name = sanitize_filename(name)
            try:
                download_mp3(mp3_url, folder_path, sanitized_name + ".mp3")
            except Exception as e:
                print(f"Error downloading episode {i}: {e}")
                continue

                    
            
            
        
        
# 測試字符是否為中文
def is_chinese(char):
    # 判斷字符的 Unicode 編碼值是否在中文範圍內
    if '\u4e00' <= char <= '\u9fff':
        return True
    else:
        return False      
    
def get_all_category():
    all_cata=['all',
     'Arts',
     'Arts / Books',
     'Arts / Design',
     'Arts / Fashion & Beauty',
     'Arts / Food',
     'Arts / Performing Arts',
     'Arts / Visual Arts',
     'Business',
     'Business / Careers',
     'Business / Entrepreneurship',
     'Business / Investing',
     'Business / Management',
     'Business / Marketing',
     'Business / Non-Profit',
     'Comedy',
     'Comedy / Comedy Interviews',
     'Comedy / Improv',
     'Comedy / Stand-Up',
     'Education',
     'Education / Courses',
     'Education / How To',
     'Education / Language Learning',
     'Education / Self-Improvement',
     'Fiction',
     'Fiction / Comedy Fiction',
     'Fiction / Drama',
     'Fiction / Science Fiction',
     'Government',
     'Health & Fitness',
     'Health & Fitness / Alternative Health',
     'Health & Fitness / Fitness',
     'Health & Fitness / Medicine',
     'Health & Fitness / Mental Health',
     'Health & Fitness / Nutrition',
     'Health & Fitness / Sexuality',
     'History',
     'Kids & Family',
     'Kids & Family / Education for Kids',
     'Kids & Family / Parenting',
     'Kids & Family / Pets & Animals',
     'Kids & Family / Stories for Kids',
     'Leisure',
     'Leisure / Animation & Manga',
     'Leisure / Automotive',
     'Leisure / Aviation',
     'Leisure / Crafts',
     'Leisure / Games',
     'Leisure / Hobbies',
     'Leisure / Home & Garden',
     'Leisure / Video Games',
     'Music',
     'Music / Music Commentary',
     'Music / Music History',
     'Music / Music Interviews',
     'News',
     'News / Business News',
     'News / Daily News',
     'News / Entertainment News',
     'News / News Commentary',
     'News / Politics',
     'News / Sports News',
     'News / Tech News',
     'Religion & Spirituality',
     'Religion & Spirituality / Buddhism',
     'Religion & Spirituality / Christianity',
     'Religion & Spirituality / Hinduism',
     'Religion & Spirituality / Islam',
     'Religion & Spirituality / Judaism',
     'Religion & Spirituality / Religion',
     'Religion & Spirituality / Spirituality',
     'Science',
     'Science / Astronomy',
     'Science / Chemistry',
     'Science / Earth Sciences',
     'Science / Life Sciences',
     'Science / Mathematics',
     'Science / Natural Sciences',
     'Science / Nature',
     'Science / Physics',
     'Science / Social Sciences',
     'Society & Culture',
     'Society & Culture / Documentary',
     'Society & Culture / Personal Journals',
     'Society & Culture / Philosophy',
     'Society & Culture / Places & Travel',
     'Society & Culture / Relationships',
     'Sports',
     'Sports / Baseball',
     'Sports / Basketball',
     'Sports / Cricket',
     'Sports / Fantasy Sports',
     'Sports / Football',
     'Sports / Golf',
     'Sports / Hockey',
     'Sports / Rugby',
     'Sports / Running',
     'Sports / Soccer',
     'Sports / Swimming',
     'Sports / Tennis',
     'Sports / Volleyball',
     'Sports / Wilderness',
     'Sports / Wrestling',
     'TV & Film',
     'TV & Film / After Shows',
     'TV & Film / Film History',
     'TV & Film / Film Interviews',
     'TV & Film / Film Reviews',
     'TV & Film / TV Reviews',
     'Technology',
     'True Crime']
    all_category=[]
    for i in range(len(all_cata)):
        all_category.append((all_cata[i].replace(" / ","-").replace(" & ","-").replace(" ","-").lower()))
    return all_category


def get_name_href(category_name):
    #抓到總排行榜   全部的網址 跟名稱
    rank_list_herf=[]
    rank_list_name=[]
    # 目標網站的URL

    url="https://rephonic.com/charts/apple/tw/"+category_name
    # 發送GET請求獲取網頁內容
    response = requests.get(url)

    # 檢查是否成功獲取網頁內容
    if response.status_code == 200:
        # 使用BeautifulSoup解析HTML
        soup = BeautifulSoup(response.content, 'html.parser')

        # 在這裡編寫你的程式碼來處理解析後的網頁內容

        # 以下是一個示例，尋找所有<a>標籤並獲取其連結和文字內容
        for link in soup.find_all('a'):
            href = link.get('href')
            text = link.get_text()
            if len(text)>0 and is_chinese(text)==True:
                #print(f"連結: {href}\t文字內容: {text}")
                rank_list_herf.append("https://rephonic.com"+href)
                rank_list_name.append(text)
            else:
                pass
    else:
        print("無法獲取網頁內容")
    return  rank_list_herf,rank_list_name



def get_rss(url):
    # 目標網頁的URL
    #url = "https://rephonic.com/podcasts/li-jing-lei-de-chen-jing-shi-jian"

    # 發送GET請求獲取網頁內容
    response = requests.get(url)

    # 檢查是否成功獲取網頁內容
    if response.status_code == 200:
        # 使用BeautifulSoup解析HTML
        soup = BeautifulSoup(response.content, 'html.parser')

        # 尋找包含RSS網址的元素
        find_rss=soup.find_all("",text=re.compile("@context"))

        # 要解析的 JSON 字串
        json_str = find_rss[0]
        # 解析 JSON 字串
        data = json.loads(json_str)
        # 提取 identifier 後面的文字
        identifier_text = data["identifier"]
        print(identifier_text)

    else:
        print("無法獲取網頁內容")
    return identifier_text

# %%
# 存放mp3檔路徑
folder_path = r"/media/starklab/BACKUP/Podcast_project/mp3//"

# #貼上rss即可下載。＃新資料夾
# 百靈果（近100集）
# get_rss_file("https://feeds.buzzsprout.com/1974862.rss","all",folder_path)
# #史塔克實驗室
get_rss_file("https://feeds.soundon.fm/podcasts/e4f101be-289a-4101-bb11-59fc61e5c88b.xml","all",folder_path)
# #跳脫Do式圈
# get_rss_file("https://feeds.soundon.fm/podcasts/22505944-fec2-4417-b277-649ce5d3a491.xml","all")
#週報時光機 (還沒)
# get_rss_file("https://feed.firstory.me/rss/user/ckcnhs4x0yuqw0918kkui2pjw","all",folder_path)
#寧可當吃貨 
# get_rss_file("https://feed.firstory.me/rss/user/cklase4t37jae0872lm9x1xmv","all",folder_path)
#科技浪 
# get_rss_file("https://feeds.soundon.fm/podcasts/03f4a53e-80cf-4a20-ad2c-bdb31a76c7b3.xml","all",folder_path)
#老高 
# get_rss_file("https://anchor.fm/s/3ba51528/podcast/rss","all")
#Joe & Jet 未過濾的 with Jason
# get_rss_file("https://feeds.soundon.fm/podcasts/78a91a6a-5c6b-43cc-aaac-7918f792e5ae.xml","all")
get_rss_file("https://feed.firstory.me/rss/user/ckruxsuzueg7v0893ho5tld70","all",folder_path)
get_rss_file("https://feed.firstory.me/rss/user/cl474kznz00ex01zpfklv4mau","all",folder_path)
# Out:
# 史塔克實驗室 一共 101 集
# 檔案下載完成: EP138. 蘋果服務業務強勁增長   台積電急擴CoWoS產能弘塑受惠.mp3
# 檔案下載完成: EP137. 史塔克月報時間 - AI產業的經濟挑戰  Tesla最新財報解析.mp3
# 檔案下載完成: EP136. 「哈拉人工智慧」: 攝影藝術新風貌  當AI成為創作夥伴  New Horizons in Photographic Art: When AI Becomes a Creative Partner.mp3
# 檔案下載完成: EP135: ChatGPT一週年 台灣企業的數位轉型之路以及觀察.mp3
# 檔案下載完成: EP20. 「史塔克月營收選股策略」：一月分機器學習個股預測.mp3
# 檔案下載完成: EP16.「史塔克月營收選股策略」：十二月份機器學習個股預測.mp3
# 檔案下載完成: EP15.「發燒新聞彙整」 : 螞蟻金服上市受阻、RCEP對於台灣的影響 、到底要不要All In台積電.mp3
# 檔案下載完成: EP13. 「機器學習開講」： 無法去日本開研討會，那大家來聽我報告吧   Using Text Mining for Financial Reports Analysis :  Long Text to Image Converter.mp3
# 檔案下載完成: EP11. 「史塔克月營收選股策略」： 十一月份機器學習個股預測.mp3
# Error downloading episode 92: [Errno 36] File name too long: '/media/starklab/BACKUP/Podcast_project/mp3//史塔克實驗室/EP10. 「發燒新聞彙報」： 大同變天  公司派喪失主場優勢  Ｏh~ Intel 竟然把NAND 晶圓事業賣了! 他們在想什麼？  滴滴出行在美上市失敗後，下一步是 香港 ？   國泰航空大裁員   港龍即起停止營運  美國金融股財報比預期好  但股價卻一路往下  講在美國大選前  預測總統誰當選.mp3'
# 檔案下載完成: EP09. 「哈拉人工智慧」：人工智慧不過就是統計學  算命好像也被講過像統計學    得證機器學習等於算命？.mp3
# 檔案下載完成: EP07. 「史塔克月營收選股策略」： 十月份機器學習個股預測.mp3
# 檔案下載完成: EP06. 「發燒新聞彙報」：  美國股市的狂瀉, 溢價DR股是黃金還是屎.mp3
# 檔案下載完成: EP05. 散戶菜雞與機器學習工程師的對話特輯.mp3
# 檔案下載完成: EP04. 「哈拉人工智慧」: 把韓國圍棋職業棋士高永夏打到懷疑人生並退出棋壇的神秘高手 - Alphago.mp3
# 檔案下載完成: EP03. 「哈拉人工智慧」:  當人類恐懼人工智慧時，到底在恐懼什麼？.mp3
# 檔案下載完成: EP02. 「史塔克月營收選股策略」： 九月份機器學習個股預測.mp3
# 檔案下載完成: EP01. 歡迎來到史塔克實驗室   機器學習是什麼 八月份的預測個股心得.mp3
# nop!an 臨時想株式會社 一共 206 集
# 檔案下載完成: EP205 奧運大爆料：比賽現場竟然有漫畫梗？.mp3
# 檔案下載完成: EP204 你不能不知道的選店小技巧.mp3
# 檔案下載完成: EP203 特教老師也能有厭世的權利嗎？feat. 黃大雄.mp3
# 檔案下載完成: EP202 為什麼你去的地方都這麼好玩！feat. 老辣妹.mp3
# 檔案下載完成: EP201 一個有聲劇的誕生 feat Ryan有聲叔 Tofu叔叔大可.mp3
# 檔案下載完成: EP200 Tomodachi Bar - 新的繼承者來了！.mp3
# 檔案下載完成: EP199 關於AI的那件小事 feat 麗臺科技 Dr. Lin.mp3
# 檔案下載完成: EP198 我也想要有個音樂型式叫阿強 feat 八十八顆芭樂籽&野球乾一杯 阿強.mp3
# 檔案下載完成: EP197 我也想當說話藝術家.mp3
# 檔案下載完成: EP196 大數據請把這集推給會劃單的人.mp3
# 檔案下載完成: EP195 這是一封寫給Podcaster的悔過書.mp3
# 檔案下載完成: EP194 忍耐只會精神內耗，發瘋可以氣死別人.mp3
# 檔案下載完成: EP193 跳進身體的舒適圈 feat. 紅犀牛 Jessie.mp3
# 檔案下載完成: EP192 解身體的渴 feat. 紅犀牛 Jessie.mp3
# 檔案下載完成: EP191 亞洲郭(ㄓ)胖(ㄨ)的美國文化衝擊  feat. 莎莎.mp3
# 檔案下載完成: EP190 完美的約會大賽 Start! (端午節版)  feat. 政大女孩悄悄話.mp3
# 檔案下載完成: EP189 我很好騙，你是否也有這種感覺 TAT.mp3
# 檔案下載完成: EP188 臨時想年度檢討大會.mp3
# 檔案下載完成: EP187 雀編的雙眼皮之路.mp3
# 檔案下載完成: EP186 DokiDoki研究所-我的安全感在哪裡？ ft.怡君.mp3
# 檔案下載完成: EP185 高度人才來碾壓 feat. 江戶川暖男.mp3
# 檔案下載完成: EP184 名店來指名挑戰 feat. 丁山肉丸的肉丸.mp3
# 檔案下載完成: EP183 特教生的新聞事件.mp3
# 檔案下載完成: EP182 天崩地裂.mp3
# 檔案下載完成: EP181 神啊!!救救我吧.mp3
# 檔案下載完成: EP180 我的過年日記.mp3
# 檔案下載完成: EP179 生活小發現 by 阿土.mp3
# 檔案下載完成: EP178 春節絕對不無聊行程指南！feat. 有要好好聊嗎？.mp3
# 檔案下載完成: EP177 王局！吃我的超派鐵拳吧！.mp3
# 檔案下載完成: EP176 絕命青年來台灣的一場大冒險 Feat. 小軟子.mp3
# 檔案下載完成: EP175 從聖誕煮到過年，來聽我們炸廚房.mp3
# 檔案下載完成: EP174 2024沒有宋北北我要怎麼投！！！Feat. 台灣綠黨中央執行委員 甘崇緯.mp3
# 檔案下載完成: EP173 多少男子戰損在迪士尼.mp3
# 檔案下載完成: EP172 平安夜要乖一點聖誕老公公才會來喔.mp3
# 檔案下載完成: EP171 我好像又說錯話了.mp3
# 檔案下載完成: EP170 隨便做做效果啦.mp3
# 檔案下載完成: EP169 我永遠會是黃色的！Feat.中信兄弟應援團長吳小白.mp3
# 檔案下載完成: EP168 一群男人的野外露音 ft. 大可、Ryan.mp3
# 檔案下載完成: EP167 我們來組個最強團體吧.mp3
# 檔案下載完成: EP166 遇到大麻煩怎麼辦?.mp3
# 檔案下載完成: EP165 中年郭胖的煩惱.mp3
# 檔案下載完成: EP164 郭胖的生存大挑戰  ft. 郭胖訓練師 莎莎.mp3
# 檔案下載完成: EP163 本集提供壓力釋放.mp3
# 檔案下載完成: EP162 我們是不是該轉換跑道了  ft. 職涯諮詢師 Brook.mp3
# 檔案下載完成: EP161 生命中必備的朋友  ft. 林筠傑 律師小雞.mp3
# 檔案下載完成: EP160 (已河蟹) DokiDoki研究所-失婚後的戀愛煩惱 ft.乾 笑死 碧珠 .mp3
# 檔案下載完成: EP159 台灣人都很玻璃心!? .mp3
# 檔案下載完成: EP158 13樣你必須擁有的禮物，尤其是第12樣最實用.mp3
# 檔案下載完成: EP157 久違的極地求生 FEAT.小雞.mp3
# 檔案下載完成: EP156 一生一定要有的雷雷旅伴.mp3
# 檔案下載完成: EP155 星期一猴子聽聲音，你﹐是猴子嗎?.mp3
# 檔案下載完成: EP154 這狀況怎麼解釋?請各位做好心理準備.mp3
# 檔案下載完成: EP153 X！這集好臭!.mp3
# 檔案下載完成: EP152 讓我們跟各位聽眾說聲父親節快樂！.mp3
# 檔案下載完成: EP151 是甚麼讓阿土從此放下了好戰的個性？.mp3
# 檔案下載完成: EP150 笑聲可以療癒人心，但預防悲劇要靠你我.mp3
# 檔案下載完成: EP149 我一直以為白飯吃到飽才是熱炒店的真諦.mp3
# 檔案下載完成: EP148 你的孩子不是你的孩子 Feat. 旅外幼教老師 Eric.mp3
# 檔案下載完成: EP147 從You Too走回Me Too Feat. 性騷擾防治觀察家台灣綠黨秘書長 彥涵.mp3
# 檔案下載完成: EP146 都在說壞話.mp3
# 檔案下載完成: EP145 肥宅驕傲周！鳥羽周作沒告訴你的秘密.mp3
# 檔案下載完成: EP144 社會的火葬場，炎上事件燒不完！.mp3
# 檔案下載完成: EP143 PUA 搭訕藝術家 Feat. 威爾  想入菲菲.mp3
# 檔案下載完成: EP142 兄弟本「色」.mp3
# 檔案下載完成: EP141 不去深究就不會有傷害 Feat.小雞.mp3
# 檔案下載完成: EP140 隱藏在心底那件最害怕的事 Feat.小雞.mp3
# 檔案下載完成: EP139 起立!立正!敬禮~~~老師好 Feat.老魏.mp3
# 檔案下載完成: EP138 小時候 vs 長大後.mp3
# 檔案下載完成: EP137 被食物深深傷害過的那個人 Feat.痛風老饕易胖體質.mp3
# 檔案下載完成: EP136 怎麼做才叫孝順 Feat.潮州小雞.mp3
# 檔案下載完成: EP135 我就說最近有些事情不對勁!.mp3
# 檔案下載完成: EP134 [F.A.T調查局] 胖有罪嗎?想減肥錯了嗎?.mp3
# 檔案下載完成: EP133 [臨時想走心] 最懂吃懂吃的胖子PK賽.mp3
# 檔案下載完成: EP132 作為一個AI語言模型.mp3
# 檔案下載完成: EP131 滯日釀酒人.mp3
# 檔案下載完成: EP130 我都是為你好.mp3
# 檔案下載完成: EP129 這是我的生存之術 Feat.潮州小雞、親愛的，尤加利葉 YEN YEN.mp3
# 檔案下載完成: EP128 炎上郭胖 Feat.ToFu叔叔 Ryan有聲叔.mp3
# 檔案下載完成: EP127 情人節完美約會法則 Feat. 乾笑死.mp3
# 檔案下載完成: EP126 豪門婚姻使用指南 Feat. 仙女.mp3
# 檔案下載完成: EP125 [Tomodachi吧] 本日新開張 - 賣笑聲解憂愁，偶爾也會賣點曖昧.mp3
# 檔案下載完成: EP124 如何讓我的媽媽、你的婆婆在過年期間快樂的不得了？.mp3
# 檔案下載完成: EP123 到底誰才是真正的大怒神 feat. 殺時間機器 蝗虫.mp3
# 檔案下載完成: EP122 一夜致富.mp3
# 檔案下載完成: EP121 我的名字就叫做文青.mp3
# 檔案下載完成: EP120 生無可戀的檢討大會即將開始.mp3
# 檔案下載完成: EP119 不學習，就等死！Feat.潮州小雞.mp3
# 檔案下載完成: EP118 我們發現了一本超級屌的書！！！ Feat.古今中歪 老熊精.mp3
# 檔案下載完成: EP117 跟上了嗎？Feat.潮州小雞.mp3
# 檔案下載完成: EP116 打擾了，您點的聖誕禮包已送到！Feat.潮州小雞.mp3
# 檔案下載完成: EP 115  里長爭霸初選秀.mp3
# 檔案下載完成: EP114 欸! 你最近忙什麼？.mp3
# 檔案下載完成: EP113 我正在探索如何變得更年輕.mp3
# 檔案下載完成: EP112 本集聊色Feat.取暖末世錄 尤奇.mp3
# 檔案下載完成: EP111 我可以，但是你不行！雙標仔集合囉~.mp3
# 檔案下載完成: EP110 哥！那只是個傳說！.mp3
# 檔案下載完成: EP109 致不再青春的你.mp3
# 檔案下載完成: EP108 台北女子圖鑑之不負責任解析.mp3
# 檔案下載完成: EP107 台北男子天菜圖鑑 Feat.TOFU叔叔.mp3
# 檔案下載完成: EP106 莫忘初衷.mp3
# 檔案下載完成: EP105 揪猴糗捏 Feat.廖邱堃.mp3
# 檔案下載完成: EP104 成為天菜的奧秘 Feat.莎莎.mp3
# 檔案下載完成: EP103 氣到差點牙起來！.mp3
# 檔案下載完成: EP102 說故事的人.mp3
# 檔案下載完成: EP101 一人分一半，感情不會散!.mp3
# 檔案下載完成: EP100   終於破百啦！歡迎插旗百集里程碑！讚讚.mp3
# 檔案下載完成: EP099 請你不要稱讚我的興趣，愛我就好！.mp3
# 檔案下載完成: EP098 笑著笑著就哭了.mp3
# 檔案下載完成: EP097 分手擂台之熟男不結婚！ Feat.彼得前女友阿喜.mp3
# 檔案下載完成: EP096 貪小便宜的最高境界！ Feat.潮州鯛魚燒.mp3
# 檔案下載完成: EP095 我有個朋友被騙去國外工作差點回不來！Feat.好棒Bump.mp3
# 檔案下載完成: EP094 除了九天玄女外的問事人選還有誰？Feat.欸!學長學長.mp3
# 檔案下載完成: EP093 終於成為二線主持人！.mp3
# 檔案下載完成: EP092 異性好友存在的是純友誼？還是蠢友誼？Feat. ulin 棕櫚樹.mp3
# 檔案下載完成: EP091 遺憾是會呼吸的痛 Feat.潮州鯛魚燒.mp3
# 檔案下載完成: EP090 大學生了沒？Feat.潮州鵰魚燒、蘆洲螢火蟲.mp3
# 檔案下載完成: EP089 臨陣磨槍好緊張！.mp3
# 檔案下載完成: EP088 意不意外、驚不驚喜、開不開心！.mp3
# 檔案下載完成: EP087 向上管理課的人生攻心計！.mp3
# 檔案下載完成: EP086 今日宜告白！心目中的女神我愛你！Feat.彥伶姐、淑芬姐.mp3
# 檔案下載完成: EP085 政治脫離民生就是詐術 Feat.毛嘉慶毛哥.mp3
# 檔案下載完成:  EP084 愛情寶貴、安全第一！！ Feat.珊珊、雅菱.mp3
# 檔案下載完成: EP083 這世上沒有酒精加音樂解決不了的煩惱！.mp3
# 檔案下載完成: EP082 今天的事情就交給明天！.mp3
# 檔案下載完成: EP081 來自客家子弟的獨白.mp3
# 檔案下載完成: EP080 日式文化果然不一樣 Feat.Kuma桑.mp3
# 檔案下載完成: EP079 勾起你心中的小惡.mp3
# 檔案下載完成: EP078  我、全、部、都、要！.mp3
# 檔案下載完成: EP077  每個人心中都有一座【二二八公園】.mp3
# 檔案下載完成: EP076  敢不敢放上OOXX的照片？.mp3
# 檔案下載完成: EP075 欸～你很幽默捏！.mp3
# 檔案下載完成: EP074 我最信任的人教會我【不要相信任何人！！！】.mp3
# 檔案下載完成: EP073 交友軟體到底該怎麼玩啦 feat. 凱特溫私雷.mp3
# 檔案下載完成: EP072 新的一年，我學著跟自己和解了.mp3
# 檔案下載完成: EP071 把錢錢變成自己喜歡的樣子！！ Feat.購物專家—歡歡.mp3
# 檔案下載完成: EP070  那是你自己の問題吧！！ Feat.漫才少爺.mp3
# 檔案下載完成: EP069 車滿就出發，一起旅行吧！.mp3
# 檔案下載完成: EP068 年初制定的目標，年底你做到了嗎？！.mp3
# 檔案下載完成: EP067 還有一天抵達聖誕節戰場！feat.最愛聖誕節的基督徒.mp3
# 檔案下載完成: EP066 算什麼男人！！！.mp3
# 檔案下載完成: EP065 台灣男孩美國夢！！！feat.小杰瓜、潮州鯛魚燒.mp3
# 檔案下載完成: EP064 【公投單選題，講你個OX！！！】 核四公投到底要怎麼投啦！feat. 台北市大安文山區 林穎孟 議員.mp3
# 檔案下載完成: EP063 當我成功的將衣服尺寸從2XL穿回S的那天！！.mp3
# 檔案下載完成: EP062  嗨，你今天屎邁爾了嗎？.mp3
# 檔案下載完成: EP061 您有一封來自中國友人的秘密訊息ㅇㅁㅇ.mp3
# 檔案下載完成: EP060 欸！聽說你今天結婚喔？！！Feat.文迪夫婦.mp3
# 檔案下載完成: EP059 【臨時講】結婚後的男人最快樂？  ft. 蒟蒻.mp3
# 檔案下載完成: EP058 【臨時講】你就差那麼一點 !!!  ft. 土雞.mp3
# 檔案下載完成: EP057 【臨時講】你可不可以勇敢一次 !!!  ft. 班尼.mp3
# 檔案下載完成: EP056 【臨時講】你有開定位嗎 !!!  ft. 羅尼.mp3
# 檔案下載完成: EP055【臨時講】酸民之所以秋條，是因為還沒遇過戰神！.mp3
# 檔案下載完成: EP054 【臨時講】天公伯請赦免我的醉！.mp3
# 檔案下載完成: EP053 【臨時講】虐多了，底線都下降了！別再對我貼標籤啦！.mp3
# 檔案下載完成: EP052 【臨時講】夢想是情懷，生存是現實，成熟的大人之路！.mp3
# 檔案下載完成: EP051【 臨時講】俗話說「老大照書養，老二照豬養」欸! 你有想過豬的感受嗎？.mp3
# 檔案下載完成: EP050 【臨時講】一個假奶 各自表述.mp3
# 檔案下載完成: EP049 【臨時講】八月運勢知多少？星座報你瞭.mp3
# 檔案下載完成: EP048 【臨時講】理智斷線還是得保持親切.mp3
# 檔案下載完成: EP047 【臨時講】精裝追女仔.mp3
# 檔案下載完成: EP046 【臨時講】刻股銘心的虐戀情深.mp3
# 檔案下載完成: EP045 【臨時講】刻不容緩 ! 屎上最急 !.mp3
# 檔案下載完成: EP044【臨時講】別喊我名字，我是你的神！盤點人生最帥氣的高光時刻。.mp3
# 檔案下載完成: EP043【臨時講】我是你的小太陽，每天充滿正能量。.mp3
# 檔案下載完成: EP042 【臨時講】慎入! 沒有假消息就是好消息.mp3
# 檔案下載完成: EP041【臨時講】我的電玩小宇宙！.mp3
# 檔案下載完成: EP040【臨時講】租屋有三害，鼠害、環境怪、跟鄰居很激掰。.mp3
# 檔案下載完成: EP039 【臨時講】我只有一句話「去你的武漢肺炎！」.mp3
# 檔案下載完成: EP038 【臨時講】這樣難笑欸Podcaster，你還挺的下去嗎?.mp3
# 檔案下載完成: EP037 【臨時講】真命天女說走就走，男人哭吧哭吧不是罪！.mp3
# 檔案下載完成: EP036 【臨時講】夏(胖)天(子)來(惶)了(恐).mp3
# 檔案下載完成: EP035 【臨時講】穩住，不要慌！一切都在預料中，我們能贏！.mp3
# 檔案下載完成: EP034 【臨時講】當男人感恩時‧‧‧‧‧‧.mp3
# 檔案下載完成: EP033 【零食劇】超譯三國：既生瑜豬哥亮 Part 33.mp3
# 檔案下載完成: EP032 【臨時講】無須原諒！.mp3
# 檔案下載完成: EP031 【零食劇】超譯三國：既生瑜豬哥亮 Part 23.mp3
# 檔案下載完成: EP030 【臨時抱佛腳】東方神秘力量「政治姓名學專家」強勢來襲Part2 Feat.欸!學長學長.mp3
# 檔案下載完成: EP029 【零食劇】超譯三國：既生瑜豬哥亮 Part 13.mp3
# 檔案下載完成: EP028 【臨時抱佛腳】東方神秘力量「政治姓名學專家」強勢來襲Part1 Feat.欸!學長學長.mp3
# 檔案下載完成: EP027 【零食劇】原來妳是這樣的白雪公主Part4 END.mp3
# 檔案下載完成: EP026 【臨時想走心】我胖我驕傲！誰才是世上最懂吃又EQ高的胖子PK賽。.mp3
# 檔案下載完成: EP025 【零食劇】原來妳是這樣的白雪公主Part3.mp3
# 檔案下載完成: EP024 【臨時講】零食劇詳解指南.mp3
# 檔案下載完成: EP023 【零食劇】原來妳是這樣的白雪公主Part2.mp3
# 檔案下載完成: EP022 【零食劇】原來妳是這樣的白雪公主Part1.mp3
# 檔案下載完成: EP021 感謝U你(>人<)   We will be back.mp3
# 檔案下載完成: EP020 這是一集關於除夕過年的趴嗑絲特別節目.mp3
# 檔案下載完成: EP019 溝通？還是通靈？動物溝通師給問嗎 Part2  Feat. kimi老師.mp3
# 檔案下載完成: EP018 溝通？還是通靈？動物溝通師給問嗎？Feat.Kimi老師.mp3
# 檔案下載完成: EP017 就問一句「敢不敢公開你的小怪癖」.mp3
# 檔案下載完成:  EP016 千層蛋餅的味道.mp3
# 檔案下載完成: EP15 身為社畜就該有社畜的模樣! ! !.mp3
# 檔案下載完成: EP14 又到了年度萬人立FLAG大會的時刻! !.mp3
# 檔案下載完成: EP13 被拒絕的勇氣Part2 ft. 蘆洲Vin Diesel.mp3
# 檔案下載完成: EP12 被拒絕的勇氣 ft. 蘆洲Vin Diesel.mp3
# 檔案下載完成: EP11 是聖誕節還是聖誕劫？直男的渡節(劫)求生指南！.mp3
# 檔案下載完成: EP10 選片如選股，外行人看熱鬧，內行人看門道，片商選片知多少？ft.吳觀影評 Part2.mp3
# 檔案下載完成: EP09 選片如選股，外行人看熱鬧，內行人看門道，片商選片知多少？ft.吳觀影評.mp3
# 檔案下載完成: EP08 那些年我們端著碗死守在電視機前的追劇時光.mp3
# 檔案下載完成: EP07 從「影視劇照師」到「校園福利社萬人迷大師！」Part2 你絕對沒想過的人生跨界斜槓旅程 ft.鹽巴老師.mp3
# 檔案下載完成: EP06  從「影視劇照師」到「校園福利社萬人迷大師！你絕對沒想過的人生跨界斜槓旅程！ft.鹽巴老師.mp3
# 檔案下載完成: SP 特別企劃 Podcast之說農趣__開心農場in real life.mp3
# 檔案下載完成: EP05 我臉書千人追蹤，但發文只有一人點讚！.mp3
# 檔案下載完成: EP04  完整解密「不可思議交友大師」的經營友誼之術.mp3
# 檔案下載完成: EP03 史上最大作弊戰爭! ! !.mp3
# 檔案下載完成: EP02 先別管酸民了，你聽過槓精嗎？.mp3
# 檔案下載完成: EP01 研究指出：在金城武樹下拍照真的不會變成金城武。.mp3
# A’s 對話日誌 一共 148 集
# 檔案下載完成: A friends time EP07.搞什麼，直接上，行不行？！feat.阿鍵、阿寶、克寧.mp3
# 檔案下載完成: S6AS02.男友打遊戲到忘我，只好主動的向你討愛.mp3
# 檔案下載完成: S6AS02.1分鐘搶先聽.mp3
# 檔案下載完成: S6AS01.關上門後的情慾才正開始.mp3
# 檔案下載完成: S5SP10.兒童節專屬 - 把你寵成我的小朋友.mp3
# 檔案下載完成: S5AAS10.欺負救命恩人大叔的小貓.mp3
# 檔案下載完成: S5AAS09.被新搬來的鄰居覬覦著R18.mp3
# 檔案下載完成: S5AAS08.婚宴換裝時，舊愛闖入了休息室R18.mp3
# 檔案下載完成: S5AAS07.婚前同學會遇到前男友R18.mp3
# 檔案下載完成: 0229 快閃日誌～４年一次不更一下嗎？.mp3
# 檔案下載完成: A friends time EP06. 姐系才香，地表最強魅力反差萌 ! 我就愛姊姊這味（feat. Blue.）.mp3
# 檔案下載完成: S5AAS06.一起等車，受不了的跑到樓梯間…R18.mp3
# 檔案下載完成: S5SP09.男友準備的生日禮.mp3
# 檔案下載完成: S5SP08. 2023年台中播客歲末年終之火鍋大亂鬥feat.播客的好朋友們.mp3
# 檔案下載完成: S5SP07. 第二屆播客聖誕活動夜之大人就該用成熟大人的方式過聖誕不是嗎？ Feat. Dr. E 嘴哥.mp3
# 檔案下載完成: ［12月份快閃日誌］－1221.mp3
# 檔案下載完成: S5AAS05 - 送你到機場，向你討了最後一次的溫存R18.mp3
# 檔案下載完成: A friends time EP05. 婊子們才該上的性愛自修事！欠砲嗎？BICH!（FT.豔星&嘴哥）.mp3
# 檔案下載完成: S5AAS04.和你享受在試衣間的刺激R18.mp3
# 檔案下載完成: 10月份快閃日誌］－1024.mp3
# 檔案下載完成: S5AAS03 -到機場接回國的男友，忍不住慾望就直接在休息室纏綿了 R18.mp3
# 檔案下載完成: ［10月快閃日誌］１０／１５.mp3
# 檔案下載完成: ［10月快閃日誌］１０／１４.mp3
# 檔案下載完成: ［10月快閃日誌］1013。.mp3
# 檔案下載完成: S5AAS02--不小心和姐妹的男友發生關係（上）R18.mp3
# 檔案下載完成: A friends time EP04. 誰說失戀只能梁靜茹，開心只能五月天？ Feat.RAY.mp3
# 檔案下載完成: ［9月快閃日誌］0920。.mp3
# 檔案下載完成: ［9月快閃日誌］0917、18、19。.mp3
# 檔案下載完成: [9月快閃日誌］0916。.mp3
# 檔案下載完成: ［9月快閃日誌］0914&15。.mp3
# 檔案下載完成: ［9月快閃日誌］0913。.mp3
# 檔案下載完成: S5AAS001--在你耳機的我［陪伴系列］.mp3
# 檔案下載完成: S5SP06. 幫加班的男友送宵夜 - 七夕特輯R18.mp3
# 檔案下載完成: S4EP10. 下班等電梯時，被副理拉進樓梯間裡吃掉了R18.mp3
# 檔案下載完成: S5SP05.  阿爸欸語音信箱 - 父親節特輯.mp3
# 檔案下載完成: ［7月快閃日誌］ 0730。.mp3
# 檔案下載完成: ［7月快閃日誌］ 0728 & 0729。.mp3
# 檔案下載完成: ［7月快閃日誌］ 0726 & 0727。.mp3
# 檔案下載完成: ［7月快閃日誌］ 0725。.mp3
# 檔案下載完成: ［7月快閃日誌］ 0724。.mp3
# 檔案下載完成: S4SP04. 取代 (Replace) R18.mp3
# 檔案下載完成: 「A friends time 」EP03 - 到底摳屁摳～是會口了膩？FEAT. 金手指－OREO.mp3
# 檔案下載完成: S4EP09. 和男友參加聚會，趁朋友喝掛在旁邊做愛 R18.mp3
# 檔案下載完成: 6月週年快閃日誌［0616］。.mp3
# 檔案下載完成: 6月週年快閃日誌［0615］。.mp3
# 檔案下載完成: 6月週年快閃日誌［0614］。.mp3
# 檔案下載完成: 6月週年快閃日誌［0612+0613］。.mp3
# 檔案下載完成: S4SP02. 箱子（The box）.mp3
# 檔案下載完成: 6月週年快閃日誌［0610+11］。.mp3
# 檔案下載完成: 「A friends time 」EP02. 讓開！我一個對多個～….但大哥你哪位啊？ Feat. MDT研究射.mp3
# 檔案下載完成: 6月週年快閃日誌［0609］。.mp3
# 檔案下載完成: S4EP08. 周末電影微醺夜，這次只准你看而已R18.mp3
# 檔案下載完成: 5月快閃日誌［0521］。.mp3
# 檔案下載完成: 5月快閃日誌［0520］。.mp3
# 檔案下載完成: 5月快閃日誌［0519］。.mp3
# 檔案下載完成: 5月快閃日誌［0517+0518］.mp3
# 檔案下載完成: 「A friends time 」- EP01. 20、30、40的三奇女子。.mp3
# 檔案下載完成: 5月快閃日誌［0516］。.mp3
# 檔案下載完成: 5月快閃日誌［0515］。.mp3
# 檔案下載完成: S4SP. Happy Mother's Day - 母親節特輯。.mp3
# 檔案下載完成: S4EP06. [日常對話] Hey，還好嗎？沒事，到我懷裡來吧。.mp3
# 檔案下載完成: S4EP05. 冒雨淋濕跑回家，被主人發現而懲罰R18.mp3
# 檔案下載完成: 4月快閃日誌［0423］.mp3
# 檔案下載完成: 4月快閃日誌［0422］.mp3
# 檔案下載完成: S4EP04. [早安起床系列] 喚醒宿醉的你.mp3
# 檔案下載完成: 4月快閃日誌［0421］.mp3
# 檔案下載完成: 4月快閃日誌［0419］.mp3
# 檔案下載完成: 4月快閃日誌［0420］.mp3
# 檔案下載完成: 4月快閃日誌［0418］.mp3
# 檔案下載完成: 4月快閃日誌［0417］ .mp3
# 檔案下載完成: S4EP03. 我的寵物奶狗情人 R18.mp3
# 檔案下載完成: 「A friends time 」-  EPISODE 00. A，妳在說什麼？.mp3
# 檔案下載完成: ［3月快閃日誌］0318《日本限定》.mp3
# 檔案下載完成: ［3月快閃日誌］0316《日本限定》.mp3
# 檔案下載完成: ［3月快閃日誌］0317《日本限定》.mp3
# 檔案下載完成: ［3月快閃日誌］0315《日本限定》.mp3
# 檔案下載完成: ［3月快閃日誌］0314 《日本限定》.mp3
# 檔案下載完成: ［3月快閃日誌］0313  《日本限定》.mp3
# 檔案下載完成: ［3月快閃日誌］0312 《日本限定》.mp3
# 檔案下載完成: ［3月快閃日誌］0311《日本限定》.mp3
# 檔案下載完成: S4EP02. 調皮女友趁男友WFH偷使壞 R18.mp3
# 檔案下載完成: ［2月快閃日誌］0218+0219。.mp3
# 檔案下載完成: ［2月快閃日誌］0217。.mp3
# 檔案下載完成: ［2月快閃日誌］0216。.mp3
# 檔案下載完成: ［2月快閃日誌］0215。.mp3
# 檔案下載完成: ［2月快閃日誌］0214。.mp3
# 檔案下載完成: S4EP01.週年紀念&情人節快樂（上）.mp3
# 檔案下載完成: S3EP10. 加班接到男友電話，忍不住只好在辦公室自己來 R18.mp3
# 檔案下載完成: S3EP09. 陪男友參加同學會，路途中忍不住就... R18.mp3
# 檔案下載完成: ［2月快閃日誌］0213。.mp3
# 檔案下載完成: ［1月限定一週快閃日誌］0130+0131.mp3
# 檔案下載完成: ［1月限定一週快閃日誌］0129.mp3
# 檔案下載完成: ［1月限定一週快閃日誌］0128.mp3
# 檔案下載完成: ［1月限定一週快閃日誌］0126+0127.mp3
# 檔案下載完成: ［1月限定一週快閃日誌］0125.mp3
# 檔案下載完成: S3EP08. ［晚安哄睡］睡前冥想。.mp3
# 檔案下載完成: S3EP07.初戀的滋味阿~我的越洋愛情故事.mp3
# 檔案下載完成: S3EP06. 送點心給正在準備期末報告的男友....  R18.mp3
# 檔案下載完成: ［12月每日限定］1230+1231。.mp3
# 檔案下載完成: ［12月每日限定］1229。.mp3
# 檔案下載完成: ［12月每日限定］1228。.mp3
# 檔案下載完成: ［12月每日限定］1227。.mp3
# 檔案下載完成: ［12月每日限定］1226。.mp3
# 檔案下載完成: ［12月每日限定］1225。.mp3
# 檔案下載完成: ［12月每日限定］1224。.mp3
# 檔案下載完成: S3EP05. 把自己當成聖誕禮物送給你R18.mp3
# 檔案下載完成: ［12月每日限定］1223。.mp3
# 檔案下載完成: ［12月每日限定］1222。.mp3
# 檔案下載完成: ［12月每日限定］1220.mp3
# 檔案下載完成: ［12月每日限定］1218。.mp3
# 檔案下載完成: ［12月每日限定］1213+1214。.mp3
# 檔案下載完成: ［12月每日限定］1212。.mp3
# 檔案下載完成: ［12月每日限定］1211下集.mp3
# 檔案下載完成: ［12月每日限定］1211上集.mp3
# 檔案下載完成: ［12月每日限定］1208。.mp3
# 檔案下載完成: ［12月每日限定］1207。.mp3
# 檔案下載完成: ［12月每日限定］1206。.mp3
# 檔案下載完成: S3EP04. 派對結束後，巧遇前任男友R18.mp3
# 檔案下載完成: ［12月每日限定］1205。.mp3
# 檔案下載完成: ［12月每日限定］1204。.mp3
# 檔案下載完成: ［12月每日限定］1203。.mp3
# 檔案下載完成: ［12月每日限定］1202。.mp3
# 檔案下載完成: ［12月每日限定］1201。.mp3
# 檔案下載完成: S3EP03. 第一次到男友家過夜.mp3
# 檔案下載完成: S3EP02.  Party後微醺的妳R18.mp3
# 檔案下載完成: S3EP01. 和出差的男友視訊愛愛玩玩具R18.mp3
# 檔案下載完成: S2EP10.我的雲端智慧情人R18.mp3
# 檔案下載完成: S2EP09. 居隔結束後，只想把妳吃掉R18.mp3
# 檔案下載完成: S2EP08. 只有趁你睡著，才敢對你說的情話。.mp3
# 檔案下載完成: S2EP07.都到了這個地步，我們分手吧。.mp3
# 檔案下載完成: S2EP06. 連假和朋友出遊露營， 趁沒人注意....R18.mp3
# 檔案下載完成: S2EP05. Mr. Stranger：Are you ready？R18.mp3
# 檔案下載完成: S2EP04.不聽話的小奶犬就該受懲罰（下）R18.mp3
# 檔案下載完成: S2EP03. A bloody love story.mp3
# 檔案下載完成: S2EP02.［晚安哄睡系列］ 確診居隔只想有你的聲音陪伴.mp3
# 檔案下載完成: S2EP01.熟悉的酒吧巧遇曾經熟悉的你R18.mp3
# 檔案下載完成: S1EP10-1.番外篇［第十集創作製作剖析］.mp3
# 檔案下載完成: S1EP10.［特別限定版］Our special relationship....mp3
# 檔案下載完成: S1EP09.趁男友開會，打電話電愛給男友聽R18.mp3
# 檔案下載完成: S1EP08.不聽話的小奶犬，就該受懲罰（上）R18.mp3
# 檔案下載完成: S1EP07.［早安起床系列］女友的特製早餐.mp3
# 檔案下載完成: S1EP06.女友的午後驚喜.mp3
# 檔案下載完成: S1EP05.加班後的來電（下）R18.mp3
# 檔案下載完成: ［Special］午後來聊一下新企劃。.mp3
# 檔案下載完成: S1EP04.加班後的來電（上）R18.mp3
# 檔案下載完成: S1EP03.和男友一起規劃未來的家.mp3
# 檔案下載完成: S1EP02.下班後的熱飯菜R18.mp3
# 檔案下載完成: S1EP01.連假結束後的女友來電。.mp3

# %%
def main():
    
    #先得到所有分類的名字
    category_name=get_all_category()
    #使用者輸入想跑多少分類
    category_n=input("你想要跑多少種分類？ 輸入數字，或者all抓取全部")
    if category_n=="all":       
        category_n=len(category_name)
    else:
        category_n=int(category_n)
    
    for i in range(category_n):      #這邊的迴圈  是指定跑幾個分類    
        #得到該分類的所有節目名稱跟網址
        rank_list_herf,rank_list_name=get_name_href(category_name[i])
        #使用者輸入想跑多少節目
        rank_list_n=5        #("一個分類想要抓取多少節目？ 輸入數字，或者all抓取全部")
        if rank_list_n=="all":    
            rank_list_n=len(rank_list_herf)
        else:
            rank_list_n=int(rank_list_n)
        
        for j in range(rank_list_n):     #這邊的迴圈  是指定跑幾個節目
            
            #得到該節目的rss
            rss_url=get_rss(rank_list_herf[j])
            #下載所有節目
            get_rss_file(rss_url,3)    #後面的後面的數字   是測試用的時候。要下載幾集。  ＃要全部的集數。 輸入"all" 
main()
# Out:
# 無法獲取網頁內容
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 28
#      26             #下載所有節目
#      27             get_rss_file(rss_url,3)    #後面的後面的數字   是測試用的時候。要下載幾集。  ＃要全部的集數。 輸入"all"
# ---> 28 main()
#
# Cell In[5], line 25, in main()
#      20     rank_list_n=int(rank_list_n)
#      22 for j in range(rank_list_n):     #這邊的迴圈  是指定跑幾個節目
#      23
#      24     #得到該節目的rss
# ---> 25     rss_url=get_rss(rank_list_herf[j])
#      26     #下載所有節目
#      27     get_rss_file(rss_url,3)
#
# IndexError: list index out of range
